# %% [markdown]
# # GPT Researcher playbook

# %% [markdown]
# <p>
# Mal Minhas, v0.1<br>
# 15.08.24
# </p>
# <p>
# <h4>Versions</h4>
# <ul>
# <li><b>v0.1</b>: 15.08.24. First version following install instructions.</li>
# </ul>
# </p>

# %% [markdown]
# ### Installation

# %% [markdown]
# You will need to [set up an OpenAI API key](https://platform.openai.com/api-keys) in `OPENAI_API_KEY` and then configure and set up an account with [Tavily](https://app.tavily.com/) for search and a `TAVILY_API_KEY` per the [Github installation instructions](https://github.com/assafelovic/gpt-researcher).  Once you have done that, the following should work:

# %% [markdown]
# ### Usage

# %%
from gpt_researcher import GPTResearcher

# %%
query = "why is Nvidia stock going up?"
researcher = GPTResearcher(query=query, report_type="research_report")
# Conduct research on the given query
research_result = await researcher.conduct_research()
# Write the report
report = await researcher.write_report()
# Out:
# 🔎 Starting the research task for 'why is Nvidia stock going up?'...
# 💰 Finance Agent
# 🗂️ I will conduct my research based on the following queries: ['Nvidia stock price increase reasons 2023', 'Nvidia financial performance and stock growth', 'Nvidia market trends and stock analysis', 'why is Nvidia stock going up?']...
#
# 🔍 Running research for 'Nvidia stock price increase reasons 2023'...
#
# 🔍 Running research for 'Nvidia financial performance and stock growth'...
#
# 🔍 Running research for 'Nvidia market trends and stock analysis'...
#
# 🔍 Running research for 'why is Nvidia stock going up?'...
# ✅ Added source url to research: https://finance.yahoo.com/news/nvidia-corp-nvda-shatters-records-215227111.html
#
# ✅ Added source url to research: https://investor.nvidia.com/financial-info/financial-reports/default.aspx
#
# ...
